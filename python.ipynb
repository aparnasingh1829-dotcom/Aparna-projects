# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnasingh1829-dotcom/Aparna-projects/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **OOPS**

# %%
class Myclass:
  x=5
p1=Myclass()
print(p1.x)
# Out:
# 5

# %%
class sum():
  def __init__(self):
    self.x=5
    self.y=7
obj=sum()
print(type(obj))
# Out:
# <class '__main__.sum'>

# %%
obj.x
# Out:
# 5

# %%
obj.y
# Out:
# 7

# %%
class atm:

  def __init__(self):
    self.pin=""
    self.balance=1000

  def menu(self):
    user_input = input("""
    How can i help you?
    Press 1 to create pin
    Press 2 to change pin
    Press 3 to check balance
    Press 4 to withdraw
    Press anything else to exit
         """)
    if user_input=="1":
      self.create_pin()
    elif user_input=="2":
      self.change_pin()
    elif user_input=="3":
      self.check_balance()
    elif user_input=="4":
      self.withdraw()
    else:
      exit()
    self.menu()

  def create_pin(self):
    pin=input("enter the pin")
    self.pin=pin
    print("pin created successfully")
    self.menu()

  def change_pin(self):
    old_pin=input("enter the old pin:")
    new_pin=input("enter the new pin:")

    if old_pin==self.pin:
       new_pin=input("enter the new pin:")
       self.pin=new_pin
       print("pin changed successfuly")
    else:
        print("invalid")
    self.menu()

  def check_balance(self):
    user_pin=input("enter the pin:")
    if user_pin==self.pin:
       print("your balance is:",self.balance)
    else:
       print("invalid")
    self.menu()

  def withdraw(self):
    user_pin=input('enter the pin:')
    if user_pin==self.pin:
      withdraw_amt=int(input("enetr the amount you want to withdraw:"))
      if withdraw_amt>self.balance:
         print("invalid transaction")
      else:
        self.balance=self.balance-withdraw_amt
        print("balance left:",self.balance)
    else:
      print("invalid")
    self.menu()

# %%
obj1 = atm()

# %%
obj1.menu()
# Out:
# pin created successfully
# invalid transaction
# your balance is: 0

# %%
class fraction:
  def __init__(self,x,y):
    self.num=x
    self.den=y
  def __str__(self):
    return "{}/{}".format(self.num,self.den)
  def __add__(self,other):
    new_num=self.num*other.den+other.num*self.den
    new_den=self.den*other.den
    return "{}/{}".format(new_num,new_den)
  def __sub__(self,other):
    new_num=self.num*other.den-other.num*self.den
    new_den=self.den*other.den
    return "{}/{}".format(new_num,new_den)
  def __mul__(self,other):
    new_num=self.num*other.num
    new_den=self.den*other.den
    return "{}/{}".format(new_num,new_den)
  def __truediv__(self,other):
    new_num=self.num*other.den
    new_den=self.den*other.num
    return "{}/{}".format(new_num,new_den)
  def convert_to_decimal(self):
    return self.num/self.den

# %%
f1=fraction(8,9)
f2=fraction(4,5)

# %%
print(f1)
# Out:
# 8/9

# %%
f1.convert_to_decimal()
# Out:
# 0.8888888888888888

# %%
print(f1 + f2)
# Out:
# 76/45

# %%
print(f1-f2)
# Out:
# 4/45

# %%
print(f1/f2)
# Out:
# 40/36

# %%
print(f1*f2)
# Out:
# 32/45
